# %% [markdown]
# # Project Work
# This project is composed from two dataset:
# - Lipidoma
# - Metaboloma
#
# The aim of this project is identify bio-markers that allow to distinguish the evolution of pathology (HCV). We have 3 several class of patient:
# - LC: Hepatocellular carcinoma
# - HC: Hepatitis C virus
# - MC: Mixed Cryoglobulinemia disease

# %% [markdown]
# ## Metaboloma

# %% [markdown]
# ### Read Data Set

# %%
import pandas as pd
import numpy as np

data_metaboloma_transpose = pd.read_excel("DataSet PAscale/Metaboloma.xlsx")
data_metaboloma_transpose

data_metaboloma = data_metaboloma_transpose.T

data_metaboloma.columns = data_metaboloma_transpose["Sample"]

data_metaboloma = data_metaboloma.iloc[1:]

data_metaboloma.columns = list(data_metaboloma.columns)

df_y_metaboloma = data_metaboloma["Label"].iloc[5:]

mz_metaboloma = data_metaboloma.iloc[0:1,1:]

df_y_qc_metaboloma = data_metaboloma["Label"].iloc[1:5]

df_x_metaboloma = pd.concat([mz_metaboloma,data_metaboloma.iloc[5:,1:]])

df_qc_metaboloma = data_metaboloma.iloc[1:5]

name_samples_metaboloma = df_x_metaboloma.transpose().columns

df_x_metaboloma
# Out:
#                               Aminooctanoic acid Androsterone sulfate  \
# m/z measured                           160.13322            369.17463
# 260522_LC 203_POS_BA3_1_5284              5593.8              8391.23
# 260522_LC 235a_POS_BA4_1_5285            4193.57              4915.16
# 260522_LC 235b_POS_BA5_1_5286            5577.39              6558.35
# 260522_LC 237_POS_BA6_1_5287              2949.2               8223.1
# ...                                          ...                  ...
# 260522_HC 019_POS_GE8_1_5367             5082.13             71447.89
# 260522_HC 020_POS_RA1_1_5368              2560.8              6213.98
# 260522_HC 021_POS_RA7_1_5375             4378.68                  NaN
# 260522_HC 022_POS_RA8_1_5376             3584.63            106970.46
# 260522_HC 023_POS_RB1_1_5377             4951.34              2153.03
#
#                               Arachidonic acid   Arginine  \
# m/z measured                         303.23318  175.11864
# 260522_LC 203_POS_BA3_1_5284           2555.37   23541.71
# 260522_LC 235a_POS_BA4_1_5285          2298.41   19442.04
# 260522_LC 235b_POS_BA5_1_5286          1886.83   15294.02
# 260522_LC 237_POS_BA6_1_5287               NaN   18433.59
# ...                                        ...        ...
# 260522_HC 019_POS_GE8_1_5367           2195.48   11581.65
# 260522_HC 020_POS_RA1_1_5368           2240.19   19817.97
# 260522_HC 021_POS_RA7_1_5375            826.61    7058.17
# 260522_HC 022_POS_RA8_1_5376           2322.56   16072.35
# 260522_HC 023_POS_RB1_1_5377           2210.14   15399.16
#
#                               Asymmetric dimethylarginine  Bilirubin  \
# m/z measured                                    203.15007  585.27057
# 260522_LC 203_POS_BA3_1_5284                     25006.24   20973.29
# 260522_LC 235a_POS_BA4_1_5285                    12460.59   16033.91
# 260522_LC 235b_POS_BA5_1_5286                    17724.85   12057.55
# 260522_LC 237_POS_BA6_1_5287                     20336.79    5485.48
# ...                                                   ...        ...
# 260522_HC 019_POS_GE8_1_5367                     11746.75     2378.9
# 260522_HC 020_POS_RA1_1_5368                     15440.64    3008.33
# 260522_HC 021_POS_RA7_1_5375                     14720.29    5098.76
# 260522_HC 022_POS_RA8_1_5376                     15300.35    8262.55
# 260522_HC 023_POS_RB1_1_5377                     11328.86    1492.71
#
#                               Biliverdin   CAR 10:0   CAR 10:1   CAR 14:1  \
# m/z measured                   583.25559  316.24831  314.23275  370.29552
# 260522_LC 203_POS_BA3_1_5284    11433.02  101834.45   27948.15   20205.67
# 260522_LC 235a_POS_BA4_1_5285    6877.93      34583   10660.89   15016.75
# 260522_LC 235b_POS_BA5_1_5286   16190.49   63739.73   20353.04   27437.44
# 260522_LC 237_POS_BA6_1_5287     7484.45   34967.29   14952.11   32336.68
# ...                                  ...        ...        ...        ...
# 260522_HC 019_POS_GE8_1_5367     1772.48   62455.74    40757.8   11739.01
# 260522_HC 020_POS_RA1_1_5368     2334.52  119343.25   55534.63   24819.22
# 260522_HC 021_POS_RA7_1_5375     3060.99  160972.44   40101.87   12816.22
# 260522_HC 022_POS_RA8_1_5376     4217.25   75388.84   25210.08   13802.58
# 260522_HC 023_POS_RB1_1_5377      883.07   27218.89   15521.81    3820.62
#
#                                ... Paraxanthine Phenylacetylglutamine  \
# m/z measured                   ...    181.07201             265.11828
# 260522_LC 203_POS_BA3_1_5284   ...     59383.52              24228.53
# 260522_LC 235a_POS_BA4_1_5285  ...     47893.61              15598.75
# 260522_LC 235b_POS_BA5_1_5286  ...     29396.64               3605.42
# 260522_LC 237_POS_BA6_1_5287   ...     13760.78               1940.63
# ...                            ...          ...                   ...
# 260522_HC 019_POS_GE8_1_5367   ...     95740.05              22130.71
# 260522_HC 020_POS_RA1_1_5368   ...     43309.66              27068.33
# 260522_HC 021_POS_RA7_1_5375   ...     31221.78              27424.89
# 260522_HC 022_POS_RA8_1_5376   ...     99036.48               16814.4
# 260522_HC 023_POS_RB1_1_5377   ...        10822               8103.98
#
#                               Pregnenolone sulfate Proline betaine  \
# m/z measured                             395.18855       144.10192
# 260522_LC 203_POS_BA3_1_5284               2319.81        11698.76
# 260522_LC 235a_POS_BA4_1_5285              3509.34        12827.33
# 260522_LC 235b_POS_BA5_1_5286              3747.13         8136.79
# 260522_LC 237_POS_BA6_1_5287               4117.25        28086.71
# ...                                            ...             ...
# 260522_HC 019_POS_GE8_1_5367              10216.19        16960.19
# 260522_HC 020_POS_RA1_1_5368               5982.11         8025.66
# 260522_HC 021_POS_RA7_1_5375               3857.13        74973.58
# 260522_HC 022_POS_RA8_1_5376              10656.49        45065.14
# 260522_HC 023_POS_RB1_1_5377               9143.15        25215.47
#
#                               Proline-hydroxyproline Pseudouridine  \
# m/z measured                               229.11857     243.06252
# 260522_LC 203_POS_BA3_1_5284                 5601.15       2336.02
# 260522_LC 235a_POS_BA4_1_5285                3854.53       2940.42
# 260522_LC 235b_POS_BA5_1_5286                2893.97       2155.48
# 260522_LC 237_POS_BA6_1_5287                 3584.11       2448.09
# ...                                              ...           ...
# 260522_HC 019_POS_GE8_1_5367                 4379.81       2054.49
# 260522_HC 020_POS_RA1_1_5368                  7901.4       3315.97
# 260522_HC 021_POS_RA7_1_5375                 4896.98       3970.25
# 260522_HC 022_POS_RA8_1_5376                 2711.33       2925.63
# 260522_HC 023_POS_RB1_1_5377                  4685.3       2824.89
#
#                               Sphingosine 1-phosphate    Taurine   Tyrosine  \
# m/z measured                                380.25458  124.00733  180.06673
# 260522_LC 203_POS_BA3_1_5284                   920.18     4491.4    3273.71
# 260522_LC 235a_POS_BA4_1_5285                  643.53    3763.71    3253.14
# 260522_LC 235b_POS_BA5_1_5286                  554.24    2540.51    8695.28
# 260522_LC 237_POS_BA6_1_5287                   502.22    4089.77    2283.71
# ...                                               ...        ...        ...
# 260522_HC 019_POS_GE8_1_5367                  1658.98    3282.69    1720.11
# 260522_HC 020_POS_RA1_1_5368                   981.54     2643.4    2377.65
# 260522_HC 021_POS_RA7_1_5375                    766.7    3415.74    2796.12
# 260522_HC 022_POS_RA8_1_5376                   587.06    4154.92    1176.92
# 260522_HC 023_POS_RB1_1_5377                  1209.32    3370.63    2494.34
#
#                               Urobilinogen
# m/z measured                     591.31872
# 260522_LC 203_POS_BA3_1_5284        893.61
# 260522_LC 235a_POS_BA4_1_5285     10207.27
# 260522_LC 235b_POS_BA5_1_5286     26167.58
# 260522_LC 237_POS_BA6_1_5287           NaN
# ...                                    ...
# 260522_HC 019_POS_GE8_1_5367       1485.28
# 260522_HC 020_POS_RA1_1_5368       2736.38
# 260522_HC 021_POS_RA7_1_5375       8934.25
# 260522_HC 022_POS_RA8_1_5376       3078.14
# 260522_HC 023_POS_RB1_1_5377       1475.84
#
# [103 rows x 53 columns]
