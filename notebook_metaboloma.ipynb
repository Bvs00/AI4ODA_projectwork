# %% [markdown]
# # Project Work
# This project is composed from two dataset:
# - Lipidoma
# - Metaboloma
#
# The aim of this project is identify bio-markers that allow to distinguish the evolution of pathology (HCV). We have 3 several class of patient:
# - LC: Hepatocellular carcinoma
# - HC: Hepatitis C virus
# - MC: Mixed Cryoglobulinemia disease

# %% [markdown]
# ## Metaboloma

# %% [markdown]
# ### Read Data Set

# %%
import pandas as pd
import numpy as np

data_metaboloma_transpose = pd.read_excel("DataSet PAscale/Metaboloma.xlsx")
data_metaboloma_transpose

data_metaboloma = data_metaboloma_transpose.T

data_metaboloma.columns = data_metaboloma_transpose["Sample"]

data_metaboloma = data_metaboloma.iloc[1:]

data_metaboloma.columns = list(data_metaboloma.columns)

df_y_metaboloma = data_metaboloma["Label"].iloc[1:]

mz_metaboloma = data_metaboloma.iloc[0:1,1:]

df_y_qc_metaboloma = data_metaboloma["Label"].iloc[1:5]

df_x_metaboloma = data_metaboloma.iloc[1:,1:]

df_qc_metaboloma = data_metaboloma.iloc[1:5]

name_samples_metaboloma = df_x_metaboloma.transpose().columns

df_x_metaboloma
# Out:
#                              Aminooctanoic acid Androsterone sulfate  \
# 260522_QC 3uL POS_BA2_1_5281            1724.36              36169.2
# 260522_QC 3uL POS_BA2_1_5282            2069.33                  NaN
# 260522_QC 3uL POS_BA2_1_5292            2345.91             36445.49
# 260522_QC 3uL POS_BA2_1_5336            2800.96             48072.08
# 260522_LC 203_POS_BA3_1_5284             5593.8              8391.23
# ...                                         ...                  ...
# 260522_HC 019_POS_GE8_1_5367            5082.13             71447.89
# 260522_HC 020_POS_RA1_1_5368             2560.8              6213.98
# 260522_HC 021_POS_RA7_1_5375            4378.68                  NaN
# 260522_HC 022_POS_RA8_1_5376            3584.63            106970.46
# 260522_HC 023_POS_RB1_1_5377            4951.34              2153.03
#
#                              Arachidonic acid  Arginine  \
# 260522_QC 3uL POS_BA2_1_5281          1791.64  20815.31
# 260522_QC 3uL POS_BA2_1_5282          2686.61  18423.92
# 260522_QC 3uL POS_BA2_1_5292          1934.77  18134.45
# 260522_QC 3uL POS_BA2_1_5336           2338.6       NaN
# 260522_LC 203_POS_BA3_1_5284          2555.37  23541.71
# ...                                       ...       ...
# 260522_HC 019_POS_GE8_1_5367          2195.48  11581.65
# 260522_HC 020_POS_RA1_1_5368          2240.19  19817.97
# 260522_HC 021_POS_RA7_1_5375           826.61   7058.17
# 260522_HC 022_POS_RA8_1_5376          2322.56  16072.35
# 260522_HC 023_POS_RB1_1_5377          2210.14  15399.16
#
#                              Asymmetric dimethylarginine Bilirubin Biliverdin  \
# 260522_QC 3uL POS_BA2_1_5281                    18192.06   2352.46    3163.69
# 260522_QC 3uL POS_BA2_1_5282                    16191.01   2867.38    2492.91
# 260522_QC 3uL POS_BA2_1_5292                    16500.87   2068.57    2921.83
# 260522_QC 3uL POS_BA2_1_5336                    18163.49   1626.92    2426.26
# 260522_LC 203_POS_BA3_1_5284                    25006.24  20973.29   11433.02
# ...                                                  ...       ...        ...
# 260522_HC 019_POS_GE8_1_5367                    11746.75    2378.9    1772.48
# 260522_HC 020_POS_RA1_1_5368                    15440.64   3008.33    2334.52
# 260522_HC 021_POS_RA7_1_5375                    14720.29   5098.76    3060.99
# 260522_HC 022_POS_RA8_1_5376                    15300.35   8262.55    4217.25
# 260522_HC 023_POS_RB1_1_5377                    11328.86   1492.71     883.07
#
#                                CAR 10:0  CAR 10:1  CAR 14:1  ... Paraxanthine  \
# 260522_QC 3uL POS_BA2_1_5281   41893.68  20112.96   13712.3  ...     25095.15
# 260522_QC 3uL POS_BA2_1_5282   45853.77   22089.3  13680.64  ...     26118.44
# 260522_QC 3uL POS_BA2_1_5292    40248.9  20480.08   14949.6  ...     34265.84
# 260522_QC 3uL POS_BA2_1_5336   38664.73   19663.5  14294.55  ...     32695.32
# 260522_LC 203_POS_BA3_1_5284  101834.45  27948.15  20205.67  ...     59383.52
# ...                                 ...       ...       ...  ...          ...
# 260522_HC 019_POS_GE8_1_5367   62455.74   40757.8  11739.01  ...     95740.05
# 260522_HC 020_POS_RA1_1_5368  119343.25  55534.63  24819.22  ...     43309.66
# 260522_HC 021_POS_RA7_1_5375  160972.44  40101.87  12816.22  ...     31221.78
# 260522_HC 022_POS_RA8_1_5376   75388.84  25210.08  13802.58  ...     99036.48
# 260522_HC 023_POS_RB1_1_5377   27218.89  15521.81   3820.62  ...        10822
#
#                              Phenylacetylglutamine Pregnenolone sulfate  \
# 260522_QC 3uL POS_BA2_1_5281               11855.6              7784.79
# 260522_QC 3uL POS_BA2_1_5282              12851.29              8463.23
# 260522_QC 3uL POS_BA2_1_5292              16378.96              9249.89
# 260522_QC 3uL POS_BA2_1_5336              13010.66             11141.93
# 260522_LC 203_POS_BA3_1_5284              24228.53              2319.81
# ...                                            ...                  ...
# 260522_HC 019_POS_GE8_1_5367              22130.71             10216.19
# 260522_HC 020_POS_RA1_1_5368              27068.33              5982.11
# 260522_HC 021_POS_RA7_1_5375              27424.89              3857.13
# 260522_HC 022_POS_RA8_1_5376               16814.4             10656.49
# 260522_HC 023_POS_RB1_1_5377               8103.98              9143.15
#
#                              Proline betaine Proline-hydroxyproline  \
# 260522_QC 3uL POS_BA2_1_5281        63059.26                4441.94
# 260522_QC 3uL POS_BA2_1_5282        59114.21                4312.64
# 260522_QC 3uL POS_BA2_1_5292        58846.07                4322.24
# 260522_QC 3uL POS_BA2_1_5336        68917.94                4249.72
# 260522_LC 203_POS_BA3_1_5284        11698.76                5601.15
# ...                                      ...                    ...
# 260522_HC 019_POS_GE8_1_5367        16960.19                4379.81
# 260522_HC 020_POS_RA1_1_5368         8025.66                 7901.4
# 260522_HC 021_POS_RA7_1_5375        74973.58                4896.98
# 260522_HC 022_POS_RA8_1_5376        45065.14                2711.33
# 260522_HC 023_POS_RB1_1_5377        25215.47                 4685.3
#
#                              Pseudouridine Sphingosine 1-phosphate  Taurine  \
# 260522_QC 3uL POS_BA2_1_5281        2532.3                  370.53  4797.76
# 260522_QC 3uL POS_BA2_1_5282       2706.49                  547.05  4898.68
# 260522_QC 3uL POS_BA2_1_5292       2988.95                  480.28  4262.75
# 260522_QC 3uL POS_BA2_1_5336       2369.77                  604.94  3894.54
# 260522_LC 203_POS_BA3_1_5284       2336.02                  920.18   4491.4
# ...                                    ...                     ...      ...
# 260522_HC 019_POS_GE8_1_5367       2054.49                 1658.98  3282.69
# 260522_HC 020_POS_RA1_1_5368       3315.97                  981.54   2643.4
# 260522_HC 021_POS_RA7_1_5375       3970.25                   766.7  3415.74
# 260522_HC 022_POS_RA8_1_5376       2925.63                  587.06  4154.92
# 260522_HC 023_POS_RB1_1_5377       2824.89                 1209.32  3370.63
#
#                              Tyrosine Urobilinogen
# 260522_QC 3uL POS_BA2_1_5281  1558.59     10739.38
# 260522_QC 3uL POS_BA2_1_5282  2369.34     10762.16
# 260522_QC 3uL POS_BA2_1_5292  1780.54     10415.68
# 260522_QC 3uL POS_BA2_1_5336  1470.27      8576.66
# 260522_LC 203_POS_BA3_1_5284  3273.71       893.61
# ...                               ...          ...
# 260522_HC 019_POS_GE8_1_5367  1720.11      1485.28
# 260522_HC 020_POS_RA1_1_5368  2377.65      2736.38
# 260522_HC 021_POS_RA7_1_5375  2796.12      8934.25
# 260522_HC 022_POS_RA8_1_5376  1176.92      3078.14
# 260522_HC 023_POS_RB1_1_5377  2494.34      1475.84
#
# [106 rows x 53 columns]

# %%
# color mapping to use in plot
color_mapping = {
    'LC': 'red',
    'MC': 'green',
    'HC' : 'orange',
    'QC' : 'purple'
}

colors = [color_mapping[label] for label in df_y_metaboloma]

# %% [markdown]
# ### View the data

# %%
import matplotlib.pyplot as plt

plt.scatter(mz_metaboloma, df_x_metaboloma.iloc[89:90])
plt.xlabel("M/Z")
plt.ylabel("Intensity")
plt.title("Samlple HC 11_M")
plt.show()
# axis=1 sono le righe; axis=0 sono le colonne
print(df_x_metaboloma[89:90].max(axis=1))
# Out:
# 260522_HC 07_POS_BD8_1_5315    268301.44
# dtype: object

# %%
df_x_metaboloma_original = df_x_metaboloma.copy()
for column in df_x_metaboloma.columns:
    df_x_metaboloma.loc[:,column] = df_x_metaboloma[column].fillna((np.nanmin(df_x_metaboloma[column]))/5)
print(df_x_metaboloma.isna().sum().sort_values(ascending=False))
# Out:
# Aminooctanoic acid                    0
# Dehydroepiandrosterone sulfate        0
# Dodecenoylcarnitine                   0
# FA 18:1+1O                            0
# Glycerophosphocholine                 0
# Histidine                             0
# Homoarginine                          0
# Hydroperoxylinoleic acid              0
# Hydroxyanthranilic acid               0
# Hydroxypregnenolone sulfate           0
# INDOLE-ACETALDEHYDE                   0
# Indoxyl sulfate                       0
# Isoleucylproline                      0
# Methylguanine                         0
# Methylhistidine                       0
# Methylpyridonecarboxamide             0
# Paraxanthine                          0
# Phenylacetylglutamine                 0
# Pregnenolone sulfate                  0
# Proline betaine                       0
# Proline-hydroxyproline                0
# Pseudouridine                         0
# Sphingosine 1-phosphate               0
# Taurine                               0
# Tyrosine                              0
# Deoxycholic acid glycine conjugate    0
# Cresol sulfate                        0
# Androsterone sulfate                  0
# Carnitine                             0
# Arachidonic acid                      0
# Arginine                              0
# Asymmetric dimethylarginine           0
# Bilirubin                             0
# Biliverdin                            0
# CAR 10:0                              0
# CAR 10:1                              0
# CAR 14:1                              0
# CAR 16:1_A                            0
# CAR 16:1_B                            0
# CAR 16:2                              0
# CAR 18:1_A                            0
# CAR 18:1_B                            0
# CAR 2:0                               0
# CAR 3:0                               0
# CAR 4:0                               0
# CAR 5:0                               0
# CAR 5:1;O2                            0
# CAR 5:1                               0
# CAR 6:0                               0
# CAR 8:0                               0
# CAR 8:1                               0
# CAR 9:0                               0
# Urobilinogen                          0
# dtype: int64

# %%
from sklearn.decomposition import PCA
pca_view = PCA(n_components=2)

scores_view = pca_view.fit_transform(df_x_metaboloma,df_y_metaboloma)


plt.scatter(scores_view[:, 0], scores_view[:, 1], c=colors)
plt.xlabel('x')
plt.ylabel('y')
plt.legend(handles=[
    plt.Line2D([0], [0], marker='o', color='w', label='LC', markerfacecolor='red', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='MC', markerfacecolor='green', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='HC', markerfacecolor='orange', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='QC', markerfacecolor='purple', markersize=10),
], title='Legend')
plt.title('PCA View')
plt.show()

# %% [markdown]
# ### TIC Normalization

# %%
# normalization with  original dataset
print(df_x_metaboloma_original.isna().sum().sort_values(ascending=False))

tic_original = df_x_metaboloma_original.sum(axis=1, skipna=True)
df_x_metaboloma_original_tic = df_x_metaboloma_original.div(tic_original,axis=0)

plt.scatter(mz_metaboloma, df_x_metaboloma_original_tic.iloc[89:90])
plt.xlabel("M/Z")
plt.ylabel("Intensity")
plt.title("Samlple HC 11_M")
plt.show()
# axis=1 sono le righe; axis=0 sono le colonne
df_x_metaboloma_original_tic[89:90].max(axis=1)
# Out:
# CAR 16:1_B                            23
# Tyrosine                              22
# CAR 16:2                              20
# Hydroxyanthranilic acid               19
# CAR 16:1_A                            18
# Hydroxypregnenolone sulfate           17
# Deoxycholic acid glycine conjugate    15
# Taurine                               15
# CAR 3:0                               14
# Hydroperoxylinoleic acid              14
# CAR 18:1_A                            13
# Methylhistidine                       12
# Pseudouridine                         12
# Urobilinogen                          12
# CAR 18:1_B                            11
# Arachidonic acid                      11
# CAR 5:1;O2                            10
# FA 18:1+1O                             9
# Aminooctanoic acid                     9
# Pregnenolone sulfate                   8
# Biliverdin                             7
# CAR 9:0                                7
# Androsterone sulfate                   7
# CAR 8:1                                6
# Sphingosine 1-phosphate                6
# Bilirubin                              6
# Cresol sulfate                         5
# Histidine                              5
# INDOLE-ACETALDEHYDE                    4
# Homoarginine                           4
# Paraxanthine                           3
# CAR 5:1                                2
# Proline-hydroxyproline                 2
# Arginine                               2
# CAR 6:0                                2
# Dodecenoylcarnitine                    1
# CAR 10:1                               1
# Indoxyl sulfate                        1
# CAR 8:0                                1
# Phenylacetylglutamine                  1
# Methylpyridonecarboxamide              1
# Proline betaine                        0
# Asymmetric dimethylarginine            0
# CAR 5:0                                0
# Methylguanine                          0
# Isoleucylproline                       0
# CAR 14:1                               0
# Glycerophosphocholine                  0
# CAR 2:0                                0
# CAR 4:0                                0
# Dehydroepiandrosterone sulfate         0
# Carnitine                              0
# CAR 10:0                               0
# dtype: int64
# 260522_HC 07_POS_BD8_1_5315    0.137752
# dtype: object

# %%
print(df_x_metaboloma.isna().sum().sort_values(ascending=False))

df_x_metaboloma_tic = df_x_metaboloma.div(tic_original,axis=0)

plt.scatter(mz_metaboloma, df_x_metaboloma_tic.iloc[89:90])
plt.xlabel("M/Z")
plt.ylabel("Intensity")
plt.title("Samlple HC 11_M")
plt.show()
# axis=1 sono le righe; axis=0 sono le colonne
df_x_metaboloma_tic[89:90].max(axis=1)
# Out:
# Aminooctanoic acid                    0
# Dehydroepiandrosterone sulfate        0
# Dodecenoylcarnitine                   0
# FA 18:1+1O                            0
# Glycerophosphocholine                 0
# Histidine                             0
# Homoarginine                          0
# Hydroperoxylinoleic acid              0
# Hydroxyanthranilic acid               0
# Hydroxypregnenolone sulfate           0
# INDOLE-ACETALDEHYDE                   0
# Indoxyl sulfate                       0
# Isoleucylproline                      0
# Methylguanine                         0
# Methylhistidine                       0
# Methylpyridonecarboxamide             0
# Paraxanthine                          0
# Phenylacetylglutamine                 0
# Pregnenolone sulfate                  0
# Proline betaine                       0
# Proline-hydroxyproline                0
# Pseudouridine                         0
# Sphingosine 1-phosphate               0
# Taurine                               0
# Tyrosine                              0
# Deoxycholic acid glycine conjugate    0
# Cresol sulfate                        0
# Androsterone sulfate                  0
# Carnitine                             0
# Arachidonic acid                      0
# Arginine                              0
# Asymmetric dimethylarginine           0
# Bilirubin                             0
# Biliverdin                            0
# CAR 10:0                              0
# CAR 10:1                              0
# CAR 14:1                              0
# CAR 16:1_A                            0
# CAR 16:1_B                            0
# CAR 16:2                              0
# CAR 18:1_A                            0
# CAR 18:1_B                            0
# CAR 2:0                               0
# CAR 3:0                               0
# CAR 4:0                               0
# CAR 5:0                               0
# CAR 5:1;O2                            0
# CAR 5:1                               0
# CAR 6:0                               0
# CAR 8:0                               0
# CAR 8:1                               0
# CAR 9:0                               0
# Urobilinogen                          0
# dtype: int64
# 260522_HC 07_POS_BD8_1_5315    0.137752
# dtype: object

# %% [markdown]
# #### View after normalization

# %%
pca_view = PCA(n_components=2)

scores_view = pca_view.fit_transform(df_x_metaboloma_tic,df_y_metaboloma)


plt.scatter(scores_view[:, 0], scores_view[:, 1], c=colors)
plt.xlabel('x')
plt.ylabel('y')
plt.legend(handles=[
    plt.Line2D([0], [0], marker='o', color='w', label='LC', markerfacecolor='red', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='MC', markerfacecolor='green', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='HC', markerfacecolor='orange', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='QC', markerfacecolor='purple', markersize=10),
], title='Legend')
plt.title('PCA View')
plt.show()

# %% [markdown]
# #### Delete outlier
# Non sono convinto che vadi bene in questo modo togliere l'outlier.
#
# Un'altra domanda è: perché non riesco a trovare che quello è un outlier (il campione rosso centrale)

# %%
# campioni da 5:73 sono LC
lc = scores_view[5:73,:]
lc_mean = lc.mean()
print(lc_mean)
mc = scores_view[73:83,:]
hc = scores_view[83:106,:]

variance_lc = pd.DataFrame({"Variance":np.var(lc,axis=1)}).sort_values(by="Variance", ascending=False)
variance_mc = pd.DataFrame({"Variance":np.var(mc,axis=1)}).sort_values(by="Variance", ascending=False)
print(variance_mc)


indexs = []
for i in range(1):
    indexs.append(variance_lc.index[i]+5)
indexs.append(71)

scores_view_ = np.delete(scores_view,indexs,axis=0)
colors_ = np.delete(colors,indexs)
# Out:
# -0.02672959522145602
#    Variance
# 0  0.082919
# 1  0.076235
# 9  0.070330
# 8  0.065402
# 4  0.064740
# 6  0.060737
# 3  0.060545
# 5  0.059539
# 7  0.053040
# 2  0.050231

# %% [markdown]
# Show the distribution of different classes

# %%
# Creare tre subplots affiancati
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

lc_ = np.delete(lc,[66,33],axis=0)

axs[0].scatter(lc_[:, 0], lc_[:, 1], c="red")
axs[0].set_title('LC')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

axs[1].scatter(mc[:, 0], mc[:, 1], c="green")
axs[1].set_title('MC')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

axs[2].scatter(hc[:, 0], hc[:, 1], c="orange")
axs[2].set_title('HC')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

fig.legend(handles=[
    plt.Line2D([0], [0], marker='o', color='w', label='LC', markerfacecolor='red', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='MC', markerfacecolor='green', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='HC', markerfacecolor='orange', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='QC', markerfacecolor='purple', markersize=10),
], title='Legend')

plt.suptitle('PCA View')

plt.show()

# %% [markdown]
# ##### View after delete outlier

# %%
plt.scatter(scores_view_[:, 0], scores_view_[:, 1], c=colors_)
plt.xlabel('x')
plt.ylabel('y')
plt.legend(handles=[
    plt.Line2D([0], [0], marker='o', color='w', label='LC', markerfacecolor='red', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='MC', markerfacecolor='green', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='HC', markerfacecolor='orange', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', label='QC', markerfacecolor='purple', markersize=10),
], title='Legend')
plt.title('PCA View')
plt.show()

# %% [markdown]
# #### Define X and Y
# Ancora non ho eliminato gli outlier.
#
# Ancora non ho diviso train e test in modo che il train abbia i campioni con maggiore varianza.

# %%
from imblearn.over_sampling import BorderlineSMOTE

df_x_metaboloma_tic_noqc = df_x_metaboloma_tic.iloc[4:]
df_y_metaboloma_noqc = df_y_metaboloma.iloc[4:]

print(df_y_metaboloma_noqc.value_counts())

x_tic = df_x_metaboloma_tic_noqc.copy()
y_tic = df_y_metaboloma_noqc.copy()

print("\nAfter drop the outleir in LC class\n")
outlier = x_tic.index[[33,66]]
x_tic = x_tic.drop(index=outlier)
y_tic = y_tic.drop(index=outlier)

name_x_tic = x_tic.transpose().columns
print(y_tic.value_counts())
plt.plot(df_y_metaboloma_noqc.value_counts())
plt.show()
# Out:
# Label
# LC    69
# HC    23
# MC    10
# Name: count, dtype: int64
#
# After drop the outleir in LC class
#
# Label
# LC    67
# HC    23
# MC    10
# Name: count, dtype: int64

# %% [markdown]
# #### Save the mean and standard deviation of the training set

# %%
mean_tic= x_tic.mean(axis=0)
std_tic = x_tic.std(axis=0)

x_tic = (x_tic.sub(mean_tic,axis=1)).div(std_tic,axis=1)

# %% [markdown]
# #### Elbow Graph

# %%
from sklearn.decomposition import PCA

varianza_spiegata_tic = []
n_componenti_tic = np.arange(1, 53)

for n in n_componenti_tic:
    pca_elbow = PCA(n_components=n)
    pca_elbow.fit(x_tic)
    varianza_spiegata_tic.append(np.sum(pca_elbow.explained_variance_ratio_))

plt.figure(figsize=(8, 6))
plt.plot(n_componenti_tic, varianza_spiegata_tic, marker='o')
plt.xlabel('# of principal components')
plt.ylabel('Explained Variance')
plt.title('Elbow Graph')
plt.grid(True)
plt.show()

# %% [markdown]
# #### PCA

# %%
pca_tic = PCA(n_components=40)
pca_tic_fit= pca_tic.fit(x_tic)
x_tic_pca = pca_tic_fit.transform(x_tic)

# %% [markdown]
# #### Pre Model

# %%
X_w_tic = pd.DataFrame(x_tic_pca)
Y_w_tic = y_tic

X_w_tic.columns = [f'PC{i}' for i in range(X_w_tic.shape[1])]
X_w_tic = X_w_tic.transpose()
X_w_tic.columns = name_x_tic
X_w_tic = X_w_tic.transpose()

all_performance = []

# %% [markdown]
# #### Fit the Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import BorderlineSMOTE
#ribilanciamento
bls = BorderlineSMOTE(random_state=99)
x,y = bls.fit_resample(X_w_tic,Y_w_tic)

FinalModel = LogisticRegression(penalty='l2', C=0.9, class_weight='balanced', multi_class='auto',max_iter=10000, n_jobs=4, solver='saga')
    
FinalModel.fit(x, y)

FinalModel
# Out:
# LogisticRegression(C=0.9, class_weight='balanced', max_iter=10000, n_jobs=4,
#                    solver='saga')

# %% [markdown]
# ## Analyze the model

# %%
print(FinalModel.classes_)
print(FinalModel.coef_[0])
print(FinalModel.n_features_in_)
print(FinalModel.feature_names_in_)


features_importance = pd.DataFrame({"PC": FinalModel.feature_names_in_, "Coefficient": abs(FinalModel.coef_[0])})
features_importance = features_importance.sort_values(by="Coefficient", ascending=False)
features_importance
# Out:
# ['HC' 'LC' 'MC']
# [ 0.19384288 -0.01791447  1.07595319 -0.48160261  0.31094892  0.06193589
#   0.16631462 -0.20594167  0.08007612  0.03711058  0.20606582 -0.04827738
#  -0.14138355  0.0152407  -0.25615701  0.07698634  0.33425085 -0.11532059
#   0.38364455  0.08085351 -0.26855459  0.16235516 -0.0570196  -0.15637954
#  -0.06098532 -0.24596787  0.10305235 -0.0714609   0.07909377  0.06008172
#   0.01836609  0.16176055  0.18357878 -0.18974616  0.30785321  0.11284742
#   0.25616862  0.03428288  0.06128165  0.07560784]
# 40
# ['PC0' 'PC1' 'PC2' 'PC3' 'PC4' 'PC5' 'PC6' 'PC7' 'PC8' 'PC9' 'PC10' 'PC11'
#  'PC12' 'PC13' 'PC14' 'PC15' 'PC16' 'PC17' 'PC18' 'PC19' 'PC20' 'PC21'
#  'PC22' 'PC23' 'PC24' 'PC25' 'PC26' 'PC27' 'PC28' 'PC29' 'PC30' 'PC31'
#  'PC32' 'PC33' 'PC34' 'PC35' 'PC36' 'PC37' 'PC38' 'PC39']
#       PC  Coefficient
# 2    PC2     1.075953
# 3    PC3     0.481603
# 18  PC18     0.383645
# 16  PC16     0.334251
# 4    PC4     0.310949
# 34  PC34     0.307853
# 20  PC20     0.268555
# 36  PC36     0.256169
# 14  PC14     0.256157
# 25  PC25     0.245968
# 10  PC10     0.206066
# 7    PC7     0.205942
# 0    PC0     0.193843
# 33  PC33     0.189746
# 32  PC32     0.183579
# 6    PC6     0.166315
# 21  PC21     0.162355
# 31  PC31     0.161761
# 23  PC23     0.156380
# 12  PC12     0.141384
# 17  PC17     0.115321
# 35  PC35     0.112847
# 26  PC26     0.103052
# 19  PC19     0.080854
# 8    PC8     0.080076
# 28  PC28     0.079094
# 15  PC15     0.076986
# 39  PC39     0.075608
# 27  PC27     0.071461
# 5    PC5     0.061936
# 38  PC38     0.061282
# 24  PC24     0.060985
# 29  PC29     0.060082
# 22  PC22     0.057020
# 11  PC11     0.048277
# 9    PC9     0.037111
# 37  PC37     0.034283
# 30  PC30     0.018366
# 1    PC1     0.017914
# 13  PC13     0.015241

# %%
# choose the most important features
imp_features_pca = features_importance.loc[features_importance["Coefficient"]>=0.2]

name_pc = imp_features_pca.T.columns
name_pc
# Out:
# Index([2, 3, 18, 16, 4, 34, 20, 36, 14, 25, 10, 7], dtype='int64')

# %%
features_imp_original = pd.DataFrame({"Feature": x_tic.columns,**{f"PC{i}":pca_tic_fit.components_[i]for i in name_pc}})
temp = features_imp_original.T
temp.columns = x_tic.columns
temp_2 = temp.T
features_imp_original = temp_2.iloc[:,1:]
features_imp_original
# Out:
#                                          PC2       PC3      PC18      PC16  \
# Aminooctanoic acid                  0.148508  0.074749 -0.186268  0.117209
# Androsterone sulfate                0.135695 -0.336849  0.165262 -0.020313
# Arachidonic acid                   -0.207967   0.17236  0.026554    0.0363
# Arginine                            0.067828  0.126368  0.259253 -0.111166
# Asymmetric dimethylarginine        -0.074609 -0.007125 -0.008641 -0.032556
# Bilirubin                          -0.099066  0.121859 -0.112475 -0.134931
# Biliverdin                         -0.190322  0.162328 -0.134771  0.052748
# CAR 10:0                            0.341398  0.134006  0.044847 -0.036576
# CAR 10:1                            0.321715  0.078577  0.016149 -0.039865
# CAR 14:1                            0.034657  0.171556  0.144776  0.067217
# CAR 16:1_A                         -0.029815  0.168029  0.056983   0.15258
# CAR 16:1_B                         -0.047035 -0.027912  0.154127 -0.071813
# CAR 16:2                            -0.02959  0.013124  0.043426  0.085791
# CAR 18:1_A                         -0.052839   -0.1361  0.090741 -0.083788
# CAR 18:1_B                           0.00658  0.098827  0.012978  0.028574
# CAR 2:0                            -0.034558 -0.041399 -0.175201 -0.102826
# CAR 3:0                             0.004143  0.051091 -0.096872  0.086305
# CAR 4:0                             0.084161   0.05961  0.415474   -0.0577
# CAR 5:0                             -0.01365 -0.030547 -0.054877 -0.024457
# CAR 5:1;O2                         -0.026149 -0.004667   0.06073 -0.058352
# CAR 5:1                            -0.027962  0.028562 -0.117052  0.184032
# CAR 6:0                             0.222599  0.144657 -0.185255 -0.066533
# CAR 8:0                              0.32217  0.107234 -0.112525 -0.086559
# CAR 8:1                             0.041592  0.022777 -0.150642  0.196411
# CAR 9:0                             0.255541 -0.064247 -0.136782  0.411687
# Carnitine                          -0.020946  -0.03387  0.026139  0.020329
# Cresol sulfate                      0.196937 -0.006732 -0.175608  0.041928
# Dehydroepiandrosterone sulfate      0.155487 -0.404281 -0.017967 -0.013295
# Deoxycholic acid glycine conjugate -0.132031   0.15272 -0.194469  0.100701
# Dodecenoylcarnitine                 0.096614   0.20358  0.095387  0.068584
# FA 18:1+1O                         -0.191209  0.163357  0.074283  0.019761
# Glycerophosphocholine              -0.194091  0.146212   0.05875  0.066778
# Histidine                           -0.03868 -0.042006 -0.022909  0.078513
# Homoarginine                        0.033299 -0.042506  0.047183 -0.379252
# Hydroperoxylinoleic acid           -0.035373 -0.046763   0.22577   0.03512
# Hydroxyanthranilic acid            -0.177461 -0.052107  0.001759 -0.159675
# Hydroxypregnenolone sulfate         0.003171 -0.296313 -0.021918  0.196049
# INDOLE-ACETALDEHYDE                -0.000889 -0.026655  0.069004  0.080989
# Indoxyl sulfate                      0.23189  0.003683 -0.074586 -0.017831
# Isoleucylproline                   -0.088721 -0.004201 -0.031583  -0.07953
# Methylguanine                      -0.074807  0.042214  0.030631  0.034797
# Methylhistidine                     -0.00032 -0.138112 -0.059587 -0.160212
# Methylpyridonecarboxamide          -0.195701 -0.084526 -0.072709 -0.152097
# Paraxanthine                         0.16781 -0.105043   0.26496 -0.155716
# Phenylacetylglutamine               0.146709   0.16037  0.024455 -0.175503
# Pregnenolone sulfate               -0.112649  -0.34946 -0.122054 -0.077778
# Proline betaine                    -0.035884 -0.112068  0.057031  0.178894
# Proline-hydroxyproline             -0.030705 -0.067573  0.352302  0.436166
# Pseudouridine                       -0.11895 -0.026367  0.128321  0.138877
# Sphingosine 1-phosphate              0.00305 -0.079632  0.095283  0.072527
# Taurine                            -0.100403 -0.190217  -0.22055  0.019712
# Tyrosine                           -0.009537  0.077759  0.077401 -0.076001
# Urobilinogen                       -0.086371  0.092244 -0.029998 -0.073276
#
#                                          PC4      PC34      PC20      PC36  \
# Aminooctanoic acid                  0.126429  0.154298 -0.057697 -0.137806
# Androsterone sulfate               -0.011819 -0.214699 -0.297591 -0.229522
# Arachidonic acid                   -0.076683 -0.008104  0.036313  0.250534
# Arginine                           -0.184653   0.11599  0.009414  0.055728
# Asymmetric dimethylarginine        -0.130314   0.12604 -0.103208 -0.259295
# Bilirubin                          -0.170378   0.09312  0.168693  -0.18196
# Biliverdin                          -0.09071 -0.028075 -0.029735 -0.005841
# CAR 10:0                             0.07287  0.038274    0.0092  -0.14601
# CAR 10:1                            0.086936 -0.102564 -0.089076  0.168705
# CAR 14:1                           -0.111416    0.1904  0.019868 -0.156927
# CAR 16:1_A                          -0.10723 -0.013637 -0.116069  0.248584
# CAR 16:1_B                         -0.065089 -0.245242 -0.013289  0.108704
# CAR 16:2                           -0.070327  0.074969  0.072443 -0.153468
# CAR 18:1_A                         -0.112723  0.270434  0.033428  0.080444
# CAR 18:1_B                         -0.001098 -0.351707  0.076451  0.009016
# CAR 2:0                             0.032837 -0.130915  0.130365  0.183049
# CAR 3:0                             0.136093  0.055229 -0.010886  0.114629
# CAR 4:0                             0.254211  0.020914 -0.069617  0.159986
# CAR 5:0                             0.103179    0.1138  0.008095 -0.062767
# CAR 5:1;O2                          0.241598 -0.030311 -0.141864  0.112096
# CAR 5:1                             0.191366  0.109843 -0.087863  0.008658
# CAR 6:0                            -0.006177 -0.009375  0.093873 -0.092728
# CAR 8:0                             0.099309  -0.03394  0.072833 -0.055867
# CAR 8:1                            -0.117641 -0.065133 -0.094746 -0.028379
# CAR 9:0                             0.073186  0.096716  0.287627  0.078979
# Carnitine                          -0.021725  0.080076  0.031509   0.03434
# Cresol sulfate                     -0.260984   0.17289 -0.056739  0.039822
# Dehydroepiandrosterone sulfate     -0.065024  0.139659 -0.196201  0.186802
# Deoxycholic acid glycine conjugate -0.116118 -0.014747 -0.365676  0.154265
# Dodecenoylcarnitine                -0.081263  0.086782 -0.130717 -0.018544
# FA 18:1+1O                          0.044235  0.086163   0.01964 -0.224938
# Glycerophosphocholine                0.04099  0.013456  0.021052 -0.104348
# Histidine                          -0.211012 -0.072992 -0.036129   -0.0071
# Homoarginine                       -0.222967 -0.023107  0.438497  0.022031
# Hydroperoxylinoleic acid           -0.092628  0.196146  0.021287 -0.045947
# Hydroxyanthranilic acid             0.270095  -0.01492  0.114701 -0.126427
# Hydroxypregnenolone sulfate        -0.213346 -0.042113  0.042093 -0.364982
# INDOLE-ACETALDEHYDE                -0.138538  -0.04073 -0.096412 -0.005925
# Indoxyl sulfate                    -0.038222 -0.404765  0.094253 -0.077764
# Isoleucylproline                     0.15393  -0.15161 -0.236399 -0.255478
# Methylguanine                      -0.211641 -0.171538 -0.125043  0.050628
# Methylhistidine                     0.099417  0.173559 -0.150923 -0.148479
# Methylpyridonecarboxamide           0.187816 -0.108535   0.13885 -0.048272
# Paraxanthine                        0.000715  0.170259 -0.068436  0.107719
# Phenylacetylglutamine              -0.100634  0.106314 -0.043088 -0.030499
# Pregnenolone sulfate               -0.115188  0.048938   0.00665  0.147833
# Proline betaine                     0.215709  0.025709  0.125477   0.02043
# Proline-hydroxyproline             -0.021679 -0.060942  0.237926 -0.085144
# Pseudouridine                       0.154606  0.004765  0.022335   0.02924
# Sphingosine 1-phosphate             -0.22206 -0.223331  0.087784  0.121266
# Taurine                             0.032445  0.095525   0.02735  0.146058
# Tyrosine                           -0.076667 -0.161102 -0.231315 -0.143784
# Urobilinogen                       -0.096804  0.097349 -0.016801   0.05769
#
#                                         PC14      PC25      PC10       PC7
# Aminooctanoic acid                 -0.061544 -0.200117  0.303058 -0.227497
# Androsterone sulfate                0.244072  0.081454 -0.020652 -0.006728
# Arachidonic acid                   -0.108603  0.131513   0.10284 -0.105202
# Arginine                           -0.044171  0.170516  0.083896 -0.001849
# Asymmetric dimethylarginine        -0.091686 -0.099601  -0.09727 -0.027893
# Bilirubin                           0.105153  0.284873   0.09707 -0.273579
# Biliverdin                          0.065718 -0.160644  0.148722  0.003146
# CAR 10:0                           -0.020857 -0.034058  0.018189 -0.065248
# CAR 10:1                            0.047858 -0.076559  0.019716 -0.120627
# CAR 14:1                            0.067567 -0.058491  -0.15023  0.162059
# CAR 16:1_A                         -0.153025   0.26028  -0.02753  0.237359
# CAR 16:1_B                          0.028701  0.174558 -0.158639  -0.11807
# CAR 16:2                            0.033484 -0.108015 -0.146358 -0.042839
# CAR 18:1_A                          -0.03492 -0.153448 -0.071466 -0.136017
# CAR 18:1_B                         -0.148292 -0.095963  0.007669  0.170014
# CAR 2:0                             0.219377  0.189271 -0.003349  0.139485
# CAR 3:0                            -0.026875  0.208394  0.047234  0.180673
# CAR 4:0                            -0.212018 -0.193598  0.053221  0.075161
# CAR 5:0                            -0.034051 -0.240948 -0.040592  0.239503
# CAR 5:1;O2                         -0.083553  0.201399  0.112478 -0.127047
# CAR 5:1                             0.176148  0.087693 -0.087463  0.150713
# CAR 6:0                             0.007194   0.06627    -0.015  0.019013
# CAR 8:0                            -0.006264  0.082179  0.049732 -0.075157
# CAR 8:1                            -0.105242 -0.112309  0.205685 -0.146146
# CAR 9:0                            -0.155317   0.17863 -0.133552 -0.166799
# Carnitine                          -0.030692  0.040463 -0.001617  -0.07893
# Cresol sulfate                     -0.099828  -0.19242 -0.051477   0.14292
# Dehydroepiandrosterone sulfate      0.093286 -0.128672   0.09611  0.040004
# Deoxycholic acid glycine conjugate   0.23433 -0.086271 -0.122999 -0.257914
# Dodecenoylcarnitine                 0.134766 -0.056087 -0.224014    0.0609
# FA 18:1+1O                         -0.119263 -0.004472   0.01445 -0.027791
# Glycerophosphocholine              -0.122894 -0.069232 -0.003126 -0.034177
# Histidine                          -0.031898  0.104217 -0.005806 -0.069008
# Homoarginine                        0.013583 -0.113124 -0.186025  0.019692
# Hydroperoxylinoleic acid           -0.079172  0.204039  0.209576  0.018848
# Hydroxyanthranilic acid             0.078032 -0.062264   0.08898 -0.120732
# Hydroxypregnenolone sulfate        -0.276492  0.195538  0.065957  0.126485
# INDOLE-ACETALDEHYDE                 0.054799 -0.007862 -0.067446 -0.062496
# Indoxyl sulfate                    -0.083443  0.013816  0.153039  -0.02754
# Isoleucylproline                   -0.156369  0.100112 -0.123052    0.2476
# Methylguanine                      -0.025874  -0.02999 -0.089138  -0.14973
# Methylhistidine                     0.055417  0.287968  -0.09761 -0.271966
# Methylpyridonecarboxamide           0.098972 -0.168431  0.124172 -0.066801
# Paraxanthine                       -0.061572  0.045534  0.104587 -0.136983
# Phenylacetylglutamine                0.03435  0.074922   0.07811  0.091721
# Pregnenolone sulfate               -0.113425  0.016113  0.095187  0.131689
# Proline betaine                    -0.016591  0.004485 -0.500725  -0.16805
# Proline-hydroxyproline              0.474917 -0.047519  0.287347  0.055201
# Pseudouridine                      -0.317994 -0.029304  0.055545 -0.196399
# Sphingosine 1-phosphate            -0.116914 -0.196695  -0.06257 -0.235803
# Taurine                            -0.155671 -0.059396  0.067393  0.036956
# Tyrosine                           -0.154307 -0.059286  0.048383 -0.092038
# Urobilinogen                         0.09237  0.031213  0.256748  0.067873

# %%
features_imp_original.mean(axis=1).sort_values(ascending=False)
# Out:
# Proline-hydroxyproline                0.127525
# CAR 3:0                                0.06243
# CAR 9:0                               0.060473
# CAR 16:1_A                            0.056376
# CAR 5:1                                0.05139
# Hydroperoxylinoleic acid              0.050908
# CAR 4:0                                0.04915
# Arginine                              0.045596
# CAR 2:0                               0.033845
# Urobilinogen                          0.032687
# CAR 14:1                              0.031753
# Phenylacetylglutamine                 0.030602
# CAR 8:0                               0.030262
# CAR 10:0                              0.029669
# Paraxanthine                           0.02782
# CAR 10:1                              0.025914
# CAR 5:1;O2                            0.021363
# Arachidonic acid                      0.020821
# Dodecenoylcarnitine                   0.019666
# CAR 6:0                               0.014878
# Aminooctanoic acid                    0.004443
# Carnitine                             0.003757
# CAR 5:0                              -0.003109
# Bilirubin                            -0.008469
# Dehydroepiandrosterone sulfate       -0.009508
# FA 18:1+1O                           -0.012149
# Pseudouridine                        -0.012944
# Hydroxyanthranilic acid              -0.013335
# Glycerophosphocholine                -0.015052
# CAR 18:1_B                           -0.015579
# Proline betaine                      -0.017132
# Biliverdin                           -0.017286
# CAR 16:2                             -0.018947
# Indoxyl sulfate                      -0.018956
# INDOLE-ACETALDEHYDE                   -0.02018
# Cresol sulfate                       -0.020774
# CAR 16:1_B                           -0.023417
# Taurine                              -0.025066
# CAR 18:1_A                           -0.025521
# Methylpyridonecarboxamide            -0.028939
# CAR 8:1                              -0.029481
# Histidine                            -0.029567
# Homoarginine                         -0.032725
# Methylhistidine                      -0.034237
# Pregnenolone sulfate                 -0.037012
# Androsterone sulfate                 -0.042641
# Hydroxypregnenolone sulfate          -0.048823
# Isoleucylproline                     -0.052108
# Deoxycholic acid glycine conjugate   -0.054017
# Methylguanine                        -0.059958
# Sphingosine 1-phosphate              -0.063091
# Tyrosine                             -0.066708
# Asymmetric dimethylarginine           -0.06718
# dtype: object
